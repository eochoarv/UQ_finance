# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.arima.model import ARIMA

from collections import defaultdict

# %%
# --- 1. Load data ---
ticker = "USDMXN=X"
sp500 = yf.Ticker(ticker)
data = sp500.history(period="6m")["Close"]
data = data.dropna()
train_size = int(len(data) * 0.8)
base_train = data[0]
base_test = data[train_size]
#data = data.diff()[1:]/np.array(data[:-1])
#data = np.log(data[1:] / np.array(data[:-1]))

# --- 2. Train/Test Split ---

train, test = data[:train_size], data[train_size:]
# Out:
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# /var/folders/9g/bj6gc6z17_1fyb7lx57xf04m0000gs/T/ipykernel_88216/1006350058.py in <module>
#       2 ticker = "USDMXN=X"
#       3 sp500 = yf.Ticker(ticker)
# ----> 4 data = sp500.history(period="6m")["Close"]
#       5 data = data.dropna()
#       6 train_size = int(len(data) * 0.8)
#
# ~/opt/anaconda3/envs/working/lib/python3.10/site-packages/yfinance/utils.py in wrapper(*args, **kwargs)
#     102
#     103         with IndentationContext():
# --> 104             result = func(*args, **kwargs)
#     105
#     106         logger.debug(f'Exiting {func.__name__}()')
#
# ~/opt/anaconda3/envs/working/lib/python3.10/site-packages/yfinance/base.py in history(self, *args, **kwargs)
#      80     @utils.log_indent_decorator
#      81     def history(self, *args, **kwargs) -> pd.DataFrame:
# ---> 82         return self._lazy_load_price_history().history(*args, **kwargs)
#      83
#      84     # ------------------------
#
# ~/opt/anaconda3/envs/working/lib/python3.10/site-packages/yfinance/base.py in _lazy_load_price_history(self)
#      86     def _lazy_load_price_history(self):
#      87         if self._price_history is None:
# ---> 88             self._price_history = PriceHistory(self._data, self.ticker, self._get_ticker_tz(self.proxy, timeout=10))
#      89         return self._price_history
#      90
#
# ~/opt/anaconda3/envs/working/lib/python3.10/site-packages/yfinance/base.py in _get_ticker_tz(self, proxy, timeout)
#     102
#     103         if tz is None:
# --> 104             tz = self._fetch_ticker_tz(proxy, timeout)
#     105             if tz is None:
#     106                 # _fetch_ticker_tz works in 99.999% of cases.
#
# ~/opt/anaconda3/envs/working/lib/python3.10/site-packages/yfinance/utils.py in wrapper(*args, **kwargs)
#     102
#     103         with IndentationContext():
# --> 104             result = func(*args, **kwargs)
#     105
#     106         logger.debug(f'Exiting {func.__name__}()')
#
# ~/opt/anaconda3/envs/working/lib/python3.10/site-packages/yfinance/base.py in _fetch_ticker_tz(self, proxy, timeout)
#     135
#     136         try:
# --> 137             data = self._data.cache_get(url=url, params=params, proxy=proxy, timeout=timeout)
#     138             data = data.json()
#     139         except YFRateLimitError:
#
# ~/opt/anaconda3/envs/working/lib/python3.10/site-packages/yfinance/data.py in wrapped(*args, **kwargs)
#      30         args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      31         kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 32         return func(*args, **kwargs)
#      33
#      34     # copy over the lru_cache extra methods to this wrapper to be able to access them
#
# ~/opt/anaconda3/envs/working/lib/python3.10/site-packages/yfinance/data.py in cache_get(self, url, user_agent_headers, params, proxy, timeout)
#     416     @lru_cache(maxsize=cache_maxsize)
#     417     def cache_get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 418         return self.get(url, user_agent_headers, params, proxy, timeout)
#     419
#     420     def _get_proxy(self, proxy):
#
# ~/opt/anaconda3/envs/working/lib/python3.10/site-packages/yfinance/utils.py in wrapper(*args, **kwargs)
#     102
#     103         with IndentationContext():
# --> 104             result = func(*args, **kwargs)
#     105
#     106         logger.debug(f'Exiting {func.__name__}()')
#
# ~/opt/anaconda3/envs/working/lib/python3.10/site-packages/yfinance/data.py in get(self, url, user_agent_headers, params, proxy, timeout)
#     347     @utils.log_indent_decorator
#     348     def get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 349         return self._make_request(url, request_method = self._session.get, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
#     350
#     351     @utils.log_indent_decorator
#
# ~/opt/anaconda3/envs/working/lib/python3.10/site-packages/yfinance/utils.py in wrapper(*args, **kwargs)
#     102
#     103         with IndentationContext():
# --> 104             result = func(*args, **kwargs)
#     105
#     106         logger.debug(f'Exiting {func.__name__}()')
#
# ~/opt/anaconda3/envs/working/lib/python3.10/site-packages/yfinance/data.py in _make_request(self, url, request_method, user_agent_headers, body, params, proxy, timeout)
#     409             # Raise exception if rate limited
#     410             if response.status_code == 429:
# --> 411                 raise YFRateLimitError()
#     412
#     413         return response
#
# YFRateLimitError: Too Many Requests. Rate limited. Try after a while.
